# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt
from pandas_datareader import data as pdr

# %%
yf.pdr_override()

# %%
stock = input("Enter a stock ticker symbol: ")
# Out:
# Enter a stock ticker symbol: QQQ

# %%
print(stock)
# Out:
# QQQ

# %%
startyear=2019
startmonth=1
startday=1

start = dt.datetime(startyear, startmonth, startday)

now = dt.datetime.now()

# %%
df=pdr.get_data_yahoo(stock, start, now)
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31  154.470001  154.979996  152.710007  154.259995  151.941101
# 2019-01-02  150.990005  155.750000  150.880005  154.880005  152.551788
# 2019-01-03  152.600006  153.259995  149.490005  149.820007  147.567871
# 2019-01-04  152.339996  157.000000  151.740005  156.229996  153.881500
# 2019-01-07  156.619995  158.860001  156.110001  158.089996  155.713531
# ...                ...         ...         ...         ...         ...
# 2021-05-18  325.390015  326.649994  321.940002  322.220001  322.220001
# 2021-05-19  316.660004  322.899994  316.299988  322.589996  322.589996
# 2021-05-20  324.119995  329.709991  323.890015  328.829987  328.829987
# 2021-05-21  330.429993  330.859985  326.640015  327.010010  327.010010
# 2021-05-24  329.369995  333.670013  326.899994  332.510010  332.510010
#
#               Volume
# Date
# 2018-12-31  53015300
# 2019-01-02  58576700
# 2019-01-03  74820200
# 2019-01-04  74709300
# 2019-01-07  52059300
# ...              ...
# 2021-05-18  36528500
# 2021-05-19  66319100
# 2021-05-20  46466100
# 2021-05-21  50284700
# 2021-05-24  32303000
#
# [604 rows x 6 columns]

# %%
ma=50
smaString = "Sma_" + str(ma)
df[smaString] = df.iloc[:, 4].rolling(window=ma).mean()

# %%
print(df)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31  154.470001  154.979996  152.710007  154.259995  151.941101
# 2019-01-02  150.990005  155.750000  150.880005  154.880005  152.551788
# 2019-01-03  152.600006  153.259995  149.490005  149.820007  147.567871
# 2019-01-04  152.339996  157.000000  151.740005  156.229996  153.881500
# 2019-01-07  156.619995  158.860001  156.110001  158.089996  155.713531
# ...                ...         ...         ...         ...         ...
# 2021-05-18  325.390015  326.649994  321.940002  322.220001  322.220001
# 2021-05-19  316.660004  322.899994  316.299988  322.589996  322.589996
# 2021-05-20  324.119995  329.709991  323.890015  328.829987  328.829987
# 2021-05-21  330.429993  330.859985  326.640015  327.010010  327.010010
# 2021-05-24  329.369995  333.670013  326.899994  332.510010  332.510010
#
#               Volume      Sma_50
# Date
# 2018-12-31  53015300         NaN
# 2019-01-02  58576700         NaN
# 2019-01-03  74820200         NaN
# 2019-01-04  74709300         NaN
# 2019-01-07  52059300         NaN
# ...              ...         ...
# 2021-05-18  36528500  327.213486
# 2021-05-19  66319100  327.437752
# 2021-05-20  46466100  327.804595
# 2021-05-21  50284700  327.992018
# 2021-05-24  32303000  328.340977
#
# [604 rows x 7 columns]

# %%
df=df.iloc[ma:]
print(df)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-14  177.130005  177.339996  176.660004  176.710007  174.053635
# 2019-03-15  177.399994  178.880005  177.279999  178.350006  175.668961
# 2019-03-18  177.949997  178.990005  177.589996  178.449997  176.087372
# 2019-03-19  179.179993  180.000000  178.289993  179.050003  176.679428
# 2019-03-20  179.059998  180.860001  178.240005  179.759995  177.380020
# ...                ...         ...         ...         ...         ...
# 2021-05-18  325.390015  326.649994  321.940002  322.220001  322.220001
# 2021-05-19  316.660004  322.899994  316.299988  322.589996  322.589996
# 2021-05-20  324.119995  329.709991  323.890015  328.829987  328.829987
# 2021-05-21  330.429993  330.859985  326.640015  327.010010  327.010010
# 2021-05-24  329.369995  333.670013  326.899994  332.510010  332.510010
#
#               Volume      Sma_50
# Date
# 2019-03-14  23751500  165.093380
# 2019-03-15  38192000  165.555724
# 2019-03-18  32935100  166.126114
# 2019-03-19  36893300  166.582072
# 2019-03-20  50105000  167.015402
# ...              ...         ...
# 2021-05-18  36528500  327.213486
# 2021-05-19  66319100  327.437752
# 2021-05-20  46466100  327.804595
# 2021-05-21  50284700  327.992018
# 2021-05-24  32303000  328.340977
#
# [554 rows x 7 columns]

# %%
numH = 0
numL = 0

for i in df.index:
    if df["Adj Close"][i] > (df[smaString][i]):
        print("The close is higher")
        numH+=1
    else:
        print("The close is lower")
        numL+=1
        
print(str(numH))
print(str(numL))
# Out:
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is lower
# The close is lower
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is higher
# The close is higher
# The close is lower
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is higher
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is higher
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is lower
# The close is higher
# The close is lower
# The close is higher
# 424
# 130
